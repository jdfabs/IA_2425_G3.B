# %%
#!/usr/bin/env python3

import board
import robot

print("SIMULATION BOARD")
simulationBoard = board.Board()
print("EMPTY BOARD")
board = board.Board()

robot = robot.Robot(board, simulationBoard)

"""
index:
    0 parede atrás
    1 parede esquerda
    2 parede frente
    3 parede direita
    4 quadrante 1
    5 quadrante 2
    6 quadrante 3
    7 quadrante 4
    """

simulationBoard.displayBoard()
print("\n\n")
board.displayBoard()

while True:
    robot.makeMove()
    
    print("\n\n")
    

# CODE TO CALIBRATE LIGHT SENSOR IF NEEDED

#robot.calibrate_light_sensor()

#while(True):
#   print(robot.crane.readSensor())

#sensorReadings = robot.crane.readCell()
#print(sensorReadings)
# Out:
# SIMULATION BOARD
# Random board generated!
# EMPTY BOARD
# Empty board set up with robot at (0, 0) and mold at (5, 5).
# +   +   +   +   +   +   +
#   R
# +   +---+   +   +   +   +
#             |       |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#   T                   B
# +   +   +   +   +   +   +
#                     |
# +   +   +   +   +   +   +
#                       M
# +   +   +   +   +   +   +
#
#
#
# +   +   +   +   +   +   +
#   R
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#                       M
# +   +   +   +   +   +   +
# TOASTER DISTANCE: None
# READ FROM SIMULATION BOARD
# Simulation Data Updated
# possibles: 5 3
# current object in cell  3
# Moving South
# Simulation Data Updated
# possibles: 5 3
# False
# None
# False
# None
# FINISHED MOVE FROM DEFAULT MOVES
#
#
#
# TOASTER DISTANCE: 2
# current object in cell  3
# Moving East
# Simulation Data Updated
# possibles: 5 3
# False
# None
# False
# None
# False
# None
# FINISHED MOVE FROM DEFAULT MOVES
#
#
#
# TOASTER DISTANCE: 3
# current object in cell  3
# Moving East
# Simulation Data Updated
# possibles: 5 3
# False
# None
# False
# None
# False
# None
# EXIT CONDITION: Robot is at x=1 with a wall on the right.
# FINISHED MOVE FROM DEFAULT MOVES
#
#
#
# TOASTER DISTANCE: 4
# current object in cell  3
# HAS BUTTER: False
# Target reached at (5, 3). Reconstructing path.
# 333
# [(5, 3), (4, 3), (3, 3), (2, 3), (2, 2)]
# 666
# Moving South
# ROBOT POSITION: ({self.current_x}, {self.current_y})
# False
# None
# False
# None
# False
# None
# FINISHED MOVE FROM A STAR
#
#
#
# SIMULATION BOARD
# +   +   +   +   +   +   +
#   R
# +   +---+   +   +   +   +
#             |       |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#   T                   B
# +   +   +   +   +   +   +
#                     |
# +   +   +   +   +   +   +
#                       M
# +   +   +   +   +   +   +
#
#
#
# robot board
# +   +   +   +   +   +   +
#
# +   +---+   +   +   +   +
#             |
# +   +   +   +   +   +   +
#           R       M
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
#
#
# TOASTER DISTANCE: None
# READ FROM SIMULATION BOARD
# Simulation Data Updated
# possibles: 5 3
# current object in cell  3
# HAS BUTTER: False
# Target reached at (5, 3). Reconstructing path.
# 333
# [(5, 3), (4, 3), (3, 3), (3, 2)]
# 666
# Moving South
# ROBOT POSITION: ({self.current_x}, {self.current_y})
# False
# None
# False
# None
# False
# None
# False
# None
# FINISHED MOVE FROM A STAR
#
#
#
# SIMULATION BOARD
# +   +   +   +   +   +   +
#   R
# +   +---+   +   +   +   +
#             |       |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#   T                   B
# +   +   +   +   +   +   +
#                     |
# +   +   +   +   +   +   +
#                       M
# +   +   +   +   +   +   +
#
#
#
# robot board
# +   +   +   +   +   +   +
#
# +   +---+   +   +   +   +
#             |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#           R       M
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
#
#
# TOASTER DISTANCE: None
# READ FROM SIMULATION BOARD
# Simulation Data Updated
# possibles: 5 3
# current object in cell  3
# HAS BUTTER: False
# Target reached at (5, 3). Reconstructing path.
# 333
# [(5, 3), (4, 3), (4, 2)]
# 666
# Moving South
# ROBOT POSITION: ({self.current_x}, {self.current_y})
# False
# None
# False
# None
# False
# None
# False
# None
# FINISHED MOVE FROM A STAR
#
#
#
# SIMULATION BOARD
# +   +   +   +   +   +   +
#   R
# +   +---+   +   +   +   +
#             |       |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#   T                   B
# +   +   +   +   +   +   +
#                     |
# +   +   +   +   +   +   +
#                       M
# +   +   +   +   +   +   +
#
#
#
# robot board
# +   +   +   +   +   +   +
#
# +   +---+   +   +   +   +
#             |
# +   +   +   +   +   +   +
#         |   |
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#           R       M
# +   +   +   +   +   +   +
#
# +   +   +   +   +   +   +
#
#
#
# TOASTER DISTANCE: None
# READ FROM SIMULATION BOARD
# Simulation Data Updated
# ONLY POSSIBLE TO WITH WITH MOLD -> TOASTER
# current object in cell  3
# HAS BUTTER: False
# No possible targets. A* search cannot proceed.
# 333
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 30
#      27 board.displayBoard()
#      29 while True:
# ---> 30     robot.makeMove()
#      32     print("\n\n")
#      35 # CODE TO CALIBRATE LIGHT SENSOR IF NEEDED
#      36
#      37 #robot.calibrate_light_sensor()
#    (...)
#      42 #sensorReadings = robot.crane.readCell()
#      43 #print(sensorReadings)
#
# File c:\Users\vigab\Documents\IA_2425_G3.B\robot.py:598, in Robot.makeMove(self)
#     596 print("333")
#     597 print(self.path)
# --> 598 chosenDirection = self.path.pop()
#     599 print("666")
#     601 new_x, new_y = chosenDirection
#
# IndexError: pop from empty list
